# %%
from bs4 import BeautifulSoup
import requests

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'} 
request_to_magicbricks = requests.get("https://www.magicbricks.com/property-for-sale/residential-real-estate?proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment,Residential-House,Villa&cityName=Hyderabad&category=B&parameter=rel&hideviewed=N&ListingsType=I&filterCount=3&incSrc=Y&fromSrc=homeSrc",headers=headers)

# %%
html_data_of_page = BeautifulSoup(request_to_magicbricks.text ,"html.parser")

# %%
script_tag= html_data_of_page.find_all("div",class_="mb-srp__list")

# %%
script_tag
# Out:
# [<div class="mb-srp__list" id="cardid75506143"><div class="mb-srp__card has-package"><div class="mb-srp__card__container"><div class="mb-srp__card__photo"><div class="mb-srp__card__photo__fig"><span class="mb-srp__card__photo__fig--count">17<span class="sign-plus">+</span> Photos</span><img alt="3 BHK Flat  for Sale in  Bowenpally, Hyderabad" class="mb-srp__card__photo__fig--graphic" decoding="async" height="100%" src="https://img.staticmb.com/mbphoto/property/cropped_images/2024/Dec/28/Photo_h300_w450/75506143_3_PropertyImage1735374287786_300_450.jpg" title="Buy 3 BHK Flat for Sale in  Bowenpally Hyderabad" width="100%"/><span class="icon-video"></span><div class="mb-srp__card__photo__fig--post">Updated today</div></div><div class="mb-srp__card__ads"><div class="mb-srp__card__ads--name">Owner: Sunny</div></div><div class="mb-srp__card__memcatgry mb-srp__card__memcatgry--premium">Premium Member</div></div><div class="mb-srp__card__info mb-srp__card__info-withoutburger"><h2 class="mb-
# ...

# %%
len(script_tag)
# Out:
# 30

# %%
script_tag[0]
# Out:
# 1
