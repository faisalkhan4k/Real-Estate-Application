# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
with open('../web-scraping/hyd-plot-data.html','r',encoding='utf-8') as f:
    html = f.read()

# %%
soup = BeautifulSoup(html,'html.parser')

# %%
all_containers = soup.find_all('div',{'class':'clasified-left'})

# %%
title=[]
price=[]
area_in_sqft=[]
location=[]

# %%
for i in all_containers:
    try:
        title.append(i.find('h2').text)
    except:
        title.append(np.nan)
    try:
        price.append(i.find('span',{'class':'pro-rice'}))
    except:
        price.append(np.nan)
    list_container = i.find('ul').find_all('li') #inside of the container html we need to find the ul
    
    area_in_sqft.append((list_container[0].find('span',{'class':'area-btm'}).text))
    location.append((list_container[1].find('span',{'class':'area-btm'}).text))
    
    # try:
    #     area_in_sqft.append(i.find('span',{'class':'area-btm'}))
    # except:
    #     area_in_sqft.append(np.nan)
    # try:
    #     location.append(i.find('span',{'class':'area-btm'}))
    # except:
    #     location.append(np.nan)

# %%
df = pd.DataFrame({
    'title':title,
    'price':price,
    'area_in_sqft':area_in_sqft,
    'location':location,
})

# %%
df.tail()
# Out:
#                                                  title             price  \
# 369  605 Sq. Yards Lands for Sale  in Adikmet, Hyde...  [Call for Price]
# 370          165 Sq. Yards Land  in Adikmet, Hyderabad  [Call for Price]
# 371  165 Sq. Yards Plot for Sale  in Adikmet, Hyder...  [Call for Price]
# 372       5 Acre Plots for Sale  in Adikmet, Hyderabad  [Call for Price]
# 373  200 Sq. Yards Open Plots for Sale  in Adikmet,...  [Call for Price]
#
#                    area_in_sqft            location
# 369  5445 sq.ft (605 Sq. Yards)  Adikmet, Hyderabad
# 370  1485 sq.ft (165 Sq. Yards)  Adikmet, Hyderabad
# 371  1485 sq.ft (165 Sq. Yards)            Freehold
# 372       217800 sq.ft (5 Acre)  Adikmet, Hyderabad
# 373  1800 sq.ft (200 Sq. Yards)         Unfurnished

# %%
df.sample(12)
# Out:
#                                                  title             price  \
# 219  147 Sq. Yards Open Plots  in Shadnagar, Hyderabad  [Call for Price]
# 112       170 Sq. Yards Plots  in Shadnagar, Hyderabad  [Call for Price]
# 9    150 Sq. Yards Lands for Sale  in Yadagirigutta...         [₹ 8 Lac]
# 42   200 Sq. Yards Plots  in Vijayawada Highway, Hy...         [₹ 5 Lac]
# 116  147 Sq. Yards Plot for Sale  in Srisailam High...  [Call for Price]
# 272  150 Sq. Yards Residential Plots for Sale  in A...  [Call for Price]
# 327         165 Sq. Yards Plots  in Adikmet, Hyderabad  [Call for Price]
# 176  147 Sq. Yards Plot for Sale  in Shadnagar, Hyd...  [Call for Price]
# 169  100 Sq. Yards Open Plots for Sale  in Yadagiri...  [Call for Price]
# 321  146.66 Sq. Yards Residential Plots for Sale  i...  [Call for Price]
# 226  200 Sq. Yards Plots for Sale  in Adibatla, Hyd...  [Call for Price]
# 352  200 Sq. Yards Residential Plots for Sale  in A...  [Call for Price]
#
#                       area_in_sqft                       location
# 219     1323 sq.ft (147 Sq. Yards)           Shadnagar, Hyderabad
# 112     1530 sq.ft (170 Sq. Yards)           Shadnagar, Hyderabad
# 9       1350 sq.ft (150 Sq. Yards)                       Freehold
# 42      1800 sq.ft (200 Sq. Yards)  Vijayawada Highway, Hyderabad
# 116     1323 sq.ft (147 Sq. Yards)                       Freehold
# 272     1350 sq.ft (150 Sq. Yards)                       Freehold
# 327     1485 sq.ft (165 Sq. Yards)             Adikmet, Hyderabad
# 176     1323 sq.ft (147 Sq. Yards)           Shadnagar, Hyderabad
# 169      900 sq.ft (100 Sq. Yards)       Yadagirigutta, Hyderabad
# 321  1320 sq.ft (146.66 Sq. Yards)             Adikmet, Hyderabad
# 226     1800 sq.ft (200 Sq. Yards)            Adibatla, Hyderabad
# 352     1800 sq.ft (200 Sq. Yards)             Adikmet, Hyderabad
